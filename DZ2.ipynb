# %%
import pandas as pd

# %% [markdown]
# ### Условие 1: 1 задача
# Скачать файл в уроке
# Считать данные с помощью pandas
# Вывести на экран первые 5 строк
# Посмотреть на описание признаков и на их содержание

# %%
df=pd.read_csv('kc_house_data.csv', encoding='windows-1251', sep=',')
df
# Out:
#                id             date     price  bedrooms  bathrooms  \
# 0      7129300520  20141013T000000  221900.0         3       1.00
# 1      6414100192  20141209T000000  538000.0         3       2.25
# 2      5631500400  20150225T000000  180000.0         2       1.00
# 3      2487200875  20141209T000000  604000.0         4       3.00
# 4      1954400510  20150218T000000  510000.0         3       2.00
# ...           ...              ...       ...       ...        ...
# 21608   263000018  20140521T000000  360000.0         3       2.50
# 21609  6600060120  20150223T000000  400000.0         4       2.50
# 21610  1523300141  20140623T000000  402101.0         2       0.75
# 21611   291310100  20150116T000000  400000.0         3       2.50
# 21612  1523300157  20141015T000000  325000.0         2       0.75
#
#        sqft_living  sqft_lot  floors  waterfront  view  ...  grade  \
# 0             1180      5650     1.0           0     0  ...      7
# ...

# %%
df.head()
# Out:
#            id             date     price  bedrooms  bathrooms  sqft_living  \
# 0  7129300520  20141013T000000  221900.0         3       1.00         1180
# 1  6414100192  20141209T000000  538000.0         3       2.25         2570
# 2  5631500400  20150225T000000  180000.0         2       1.00          770
# 3  2487200875  20141209T000000  604000.0         4       3.00         1960
# 4  1954400510  20150218T000000  510000.0         3       2.00         1680
#
#    sqft_lot  floors  waterfront  view  ...  grade  sqft_above  sqft_basement  \
# 0      5650     1.0           0     0  ...      7        1180              0
# 1      7242     2.0           0     0  ...      7        2170            400
# 2     10000     1.0           0     0  ...      6         770              0
# 3      5000     1.0           0     0  ...      7        1050            910
# 4      8080     1.0           0     0  ...      8        1680              0
#
# ...

# %% [markdown]
# #### Условие 2: 2 задача
# Проведите первичный анализ данных
# Изучите типы данных
# Найдите количество пропущенных ячеек в данных
# Посчитайте основные статистики по всем признакам и поизучайте их
# Пишите выводы

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 21613 entries, 0 to 21612
# Data columns (total 21 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   id             21613 non-null  int64
#  1   date           21613 non-null  object
#  2   price          21613 non-null  float64
#  3   bedrooms       21613 non-null  int64
#  4   bathrooms      21613 non-null  float64
#  5   sqft_living    21613 non-null  int64
#  6   sqft_lot       21613 non-null  int64
#  7   floors         21613 non-null  float64
#  8   waterfront     21613 non-null  int64
#  9   view           21613 non-null  int64
#  10  condition      21613 non-null  int64
#  11  grade          21613 non-null  int64
#  12  sqft_above     21613 non-null  int64
#  13  sqft_basement  21613 non-null  int64
#  14  yr_built       21613 non-null  int64
#  15  yr_renovated   21613 non-null  int64
#  16  zipcode        21613 non-null  int64
# ...

# %%
df.describe()
# Out:
#                  id         price      bedrooms     bathrooms   sqft_living  \
# count  2.161300e+04  2.161300e+04  21613.000000  21613.000000  21613.000000
# mean   4.580302e+09  5.400881e+05      3.370842      2.114757   2079.899736
# std    2.876566e+09  3.671272e+05      0.930062      0.770163    918.440897
# min    1.000102e+06  7.500000e+04      0.000000      0.000000    290.000000
# 25%    2.123049e+09  3.219500e+05      3.000000      1.750000   1427.000000
# 50%    3.904930e+09  4.500000e+05      3.000000      2.250000   1910.000000
# 75%    7.308900e+09  6.450000e+05      4.000000      2.500000   2550.000000
# max    9.900000e+09  7.700000e+06     33.000000      8.000000  13540.000000
#
#            sqft_lot        floors    waterfront          view     condition  \
# count  2.161300e+04  21613.000000  21613.000000  21613.000000  21613.000000
# mean   1.510697e+04      1.494309      0.007542      0.234303      3.409430
# ...

# %%
df['sqft_lot'].min()
# Out:
# 520

# %%
df.describe(include=['object'])
# Out:
#                    date
# count             21613
# unique              372
# top     20140623T000000
# freq                142

# %% [markdown]
# ###### Выводы.
# Документ df содержит следующие типы данных: float64(5 столбцов), int64(15 стобцов), object(1 столбец). В документе нет пропущенных ячеек. Документ содержит 21613 строк × 21 столбец.
#
# Общее количество жилых объектов 21612.
# Средняя цена объекта: 540081 ден. ед.
# Минимальная цена объекта: 75000 ден.ед.
# Максимальная цена объекта:7700000 ден.ед.
# Средняя площадь объектов 15106
# Минимальная площадь: 520
# Максимальная площадь: 1651359
# Среднее состояние объектов (по пятибальной шкале): 3,4
# Средний возраст объектов: 47 лет
# Самые старые объекты построены в 1900 году
# Самые молодые объекты построены в 2015 году
# Средний класс объектов: 7.65
# Минимальный класс: 1.17
# Максимальный класс: 13.00
# Объекты в таблице делятся на удаленность от береговой линии.
# Также есть объекты которые включают подвальные помещения.

# %% [markdown]
# #### Условие 3: 3 задача
# Ответьте на несколько вопросов
# 3.1 В каком диапазоне изменяются стоимости недвижимости?
# 3.2 Какую долю в среднем занимают жилая площадь от всей площади по всем домам?
# 3.3 Как много домов с разными этажами в данных?
# 3.4 Насколько хорошие состояния у домов в данных?
# 3.5 Найдите года, когда построили первый дом, когда построили последний дом в данных?

# %% [markdown]
# ##### 3.1 В каком диапазоне изменяются стоимости недвижимости?

# %%
df['price'].value_counts()
# Out:
# price
# 350000.0     172
# 450000.0     172
# 550000.0     159
# 500000.0     152
# 425000.0     150
#             ...
# 607010.0       1
# 1362500.0      1
# 298800.0       1
# 957500.0       1
# 402101.0       1
# Name: count, Length: 4028, dtype: int64

# %%
df['price'].min()
# Out:
# 75000.0

# %%
df['price'].max()
# Out:
# 7700000.0

# %% [markdown]
# Стоимость изменяется в диапазоне от 75000 ден. ед до 7700000 ден.ед.

# %% [markdown]
# ##### 3.2 Какую долю в среднем занимают жилая площадь от всей площади по всем домам?

# %%
df['sqft_living'].mean()/df['sqft_lot'].mean()*100
# Out:
# 13.76781757959227

# %% [markdown]
# ##### 3.3 Как много домов с разными этажами в данных?

# %%
df['floors'].value_counts()
# Out:
# floors
# 1.0    10680
# 2.0     8241
# 1.5     1910
# 3.0      613
# 2.5      161
# 3.5        8
# Name: count, dtype: int64

# %% [markdown]
# ##### 3.4 Насколько хорошие состояния у домов в данных?

# %%
df['condition'].value_counts(normalize=True)*100
# Out:
# condition
# 3    64.919262
# 4    26.275852
# 5     7.870263
# 2     0.795817
# 1     0.138805
# Name: proportion, dtype: float64

# %% [markdown]
# ##### 3.5 Найдите года, когда построили первый дом, когда построили последний дом в данных?

# %%
df['yr_built'].min(),df['yr_built'].max()
# Out:
# (1900, 2015)

# %% [markdown]
# #### Условие 4: 4 задача
# Ответьте на несколько вопросов
#
# 4.1 Сколько в среднем стоят дома, у которых 2 спальни?
# 4.2 Какая в среднем общая площадь домов, у которых стоимость больше 600 000?
# 4.3 Как много домов коснулся ремонт?
# 4.4 Насколько в среднем стоимость домов с оценкой grade домов выше 10 отличается от стоимости домов с оценкой grade меньше 4?

# %% [markdown]
# #### 4.1 Сколько в среднем стоят дома, у которых 2 спальни?

# %%
df2=df[df['bedrooms']==2]
df2
# Out:
#                id             date     price  bedrooms  bathrooms  \
# 2      5631500400  20150225T000000  180000.0         2       1.00
# 11     9212900260  20140527T000000  468000.0         2       1.00
# 18       16000397  20141205T000000  189000.0         2       1.00
# 23     8091400200  20140516T000000  252700.0         2       1.50
# 31     2426039314  20141201T000000  280000.0         2       1.50
# ...           ...              ...       ...       ...        ...
# 21586  2767604724  20141015T000000  505000.0         2       2.50
# 21588  2767600688  20141113T000000  414500.0         2       1.50
# 21595  1972201967  20141031T000000  520000.0         2       2.25
# 21610  1523300141  20140623T000000  402101.0         2       0.75
# 21612  1523300157  20141015T000000  325000.0         2       0.75
#
#        sqft_living  sqft_lot  floors  waterfront  view  ...  grade  \
# 2              770     10000     1.0           0     0  ...      6
# ...

# %%
mean_price=df2['price'].mean()
mean_price
# Out:
# 401372.681884058

# %% [markdown]
# ##### 4.2 Какая в среднем общая площадь домов, у которых стоимость больше 600 000?

# %%
df[df['price']>=600000]['sqft_lot'].mean()
# Out:
# 20454.783537543197

# %% [markdown]
# ##### 4.3 Как много домов коснулся ремонт?

# %%
df[df['yr_renovated']!=0].shape[0]
# Out:
# 914

# %% [markdown]
# ##### 4.4 Насколько в среднем стоимость домов с оценкой grade домов выше 10 отличается от стоимости домов с оценкой grade меньше 4?

# %%
df[df['grade']>10]['price'].mean()-df[df['grade']<4]['price'].mean()
# Out:
# 1488885.1175298805

# %% [markdown]
# #### Условие 5: 5 задача
# Ответьте на несколько вопросов
# 5.1 Выберите дом клиенту
# Клиент хочет дом с видом на набережную, как минимум с тремя ванными и с подвалом. Сколько вариантов есть у клиента?
# 5.2 Выберите дом клиенту
# Клиент хочет дом либо с очень красивым видом из окна, либо с видом на набережную, в очень хорошем состоянии и год постройки не меньше 1980 года. В какой ценовом диапазоне будут дома?
# 5.3 Выберите дом клиенту
# Клиент хочет дом без подвала, с двумя этажами, стоимостью до 150000. Какая оценка по состоянию у таких домов в среднем?

# %% [markdown]
# ##### 5.1 Выберите дом клиенту
# Клиент хочет дом с видом на набережную, как минимум с тремя ванными и с подвалом. Сколько вариантов есть у клиента?

# %%
df_end=df[(df['waterfront']==1)&
   (df['bathrooms']>=3)&
   ~(df['sqft_basement']==0)]
df_end.shape[0]
# Out:
# 41

# %% [markdown]
# ##### 5.2 Выберите дом клиенту
# Клиент хочет дом либо с очень красивым видом из окна, либо с видом на набережную, в очень хорошем состоянии и год постройки не меньше 1980 года. В какой ценовом диапазоне будут дома?

# %%
df3=df[df['yr_built']>=1980]
df3
# Out:
#                id             date      price  bedrooms  bathrooms  \
# 4      1954400510  20150218T000000   510000.0         3       2.00
# 5      7237550310  20140512T000000  1225000.0         4       4.50
# 6      1321400060  20140627T000000   257500.0         3       2.25
# 9      3793500160  20150312T000000   323000.0         3       2.50
# 16     1875500060  20140731T000000   395000.0         3       2.00
# ...           ...              ...        ...       ...        ...
# 21608   263000018  20140521T000000   360000.0         3       2.50
# 21609  6600060120  20150223T000000   400000.0         4       2.50
# 21610  1523300141  20140623T000000   402101.0         2       0.75
# 21611   291310100  20150116T000000   400000.0         3       2.50
# 21612  1523300157  20141015T000000   325000.0         2       0.75
#
#        sqft_living  sqft_lot  floors  waterfront  view  ...  grade  \
# 4             1680      8080     1.0           0     0  ...      8
# ...

# %%
df_end2=df3[(df3['view']==4)|(df3['waterfront']==1)&(df3['condition']==5)]
df_end2
# Out:
#                id             date      price  bedrooms  bathrooms  \
# 246    2025069065  20140929T000000  2400000.0         4       2.50
# 300    3225069065  20140624T000000  3075000.0         4       5.00
# 409    1560930070  20140911T000000   840000.0         4       3.50
# 757    9273200140  20150121T000000  1310000.0         2       2.25
# 1164   1247600105  20141020T000000  5110800.0         5       5.25
# ...           ...              ...        ...       ...        ...
# 20767  8043700105  20150417T000000  2300000.0         4       4.00
# 20923  7852070210  20140527T000000  1149000.0         4       3.00
# 21050  2424059170  20150219T000000   900000.0         5       6.00
# 21201   518500460  20141008T000000  2230000.0         3       3.50
# 21576  9253900271  20150107T000000  3567000.0         5       4.50
#
#        sqft_living  sqft_lot  floors  waterfront  view  ...  grade  \
# 246           3650      8354     1.0           1     4  ...      9
# ...

# %% [markdown]
# ##### В какой ценовом диапазоне будут дома?

# %%
df_end2['price'].min(),df_end2['price'].max()
# Out:
# (380000.0, 6885000.0)

# %% [markdown]
# ##### 5.3 Выберите дом клиенту
# Клиент хочет дом без подвала, с двумя этажами, стоимостью до 150000. Какая оценка по состоянию у таких домов в среднем?

# %%
df5=df[(df['sqft_basement']==0)&
   (df['floors']==2)&
   (df['price']<150000)
   ]
df5
# Out:
#                id             date     price  bedrooms  bathrooms  \
# 2589   5061300030  20140508T000000  134000.0         2       1.50
# 10105  5466310060  20150324T000000  139500.0         2       1.50
# 15610  7614100080  20150211T000000  140000.0         3       1.75
# 18332  9272202260  20140924T000000  130000.0         3       1.00
# 18939  4239400300  20141129T000000   90000.0         3       1.00
# 18988  7399100210  20141126T000000  140000.0         3       1.50
#
#        sqft_living  sqft_lot  floors  waterfront  view  ...  grade  \
# 2589           980      5000     2.0           0     0  ...      7
# 10105         1230      1561     2.0           0     0  ...      7
# 15610         1270      8991     2.0           0     0  ...      7
# 18332         1200      7000     2.0           0     0  ...      7
# 18939          980      2490     2.0           0     0  ...      6
# 18988         1200      2002     2.0           0     0  ...      8
#
# ...

# %%
df5['condition'].mean()
# Out:
# 2.8333333333333335
